# %%
import pandas as pd
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/My Drive/') #切換該目錄

# %%
col_names = ["col1", "col2", "col3","col4","col5", "col6","col7", "col8", "col9","col10", "col11", "col12",
        "col13", "col14", "col15","col16", "col17", "col18","col19", "col20", "col21","col22", "col23",
        "col24","col25", "col26", "col27","col28", "col29", "col30","col31", "col32", "col33","col34", "col35", "col36","col37", "col38", "col39", "col40"]
df = pd.read_csv('/content/drive/My Drive/全合併.csv', names=col_names, header=None,engine = 'python', error_bad_lines=False)
df.head()
# Out:
#                                     col1              col2  ... col39 col40
# 0                                   鄉鎮市區              None  ...   NaN   NaN
# 1  The villages and towns urban district  transaction sign  ...   NaN   NaN
# 2                                    大安區         房地(土地+建物)  ...   NaN   NaN
# 3                                    中正區         房地(土地+建物)  ...   NaN   NaN
# 4                                    大同區                土地  ...   NaN   NaN
#
# [5 rows x 40 columns]

# %%
len(df)
# Out:
# 3215673

# %%
df.head(10)
# Out:
#                                     col1              col2  ... col39 col40
# 0                                   鄉鎮市區              None  ...   NaN   NaN
# 1  The villages and towns urban district  transaction sign  ...   NaN   NaN
# 2                                    大安區         房地(土地+建物)  ...   NaN   NaN
# 3                                    中正區         房地(土地+建物)  ...   NaN   NaN
# 4                                    大同區                土地  ...   NaN   NaN
# 5                                    大同區         房地(土地+建物)  ...   NaN   NaN
# 6                                    內湖區         房地(土地+建物)  ...   NaN   NaN
# 7                                    信義區                土地  ...   NaN   NaN
# 8                                    松山區                土地  ...   NaN   NaN
# 9                                    松山區         房地(土地+建物)  ...   NaN   NaN
#
# [10 rows x 40 columns]

# %%
df = df.drop(["col37", "col38", "col39", "col40"], axis = 1,inplace=True)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ad6682260274> in <module>()
#       1 df = df.drop(["col37", "col38", "col39", "col40"], axis = 1,inplace=True)
# ----> 2 df.head(10)
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
df = df.loc[2:]
df.index = range(1,len(df)+1)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-993a3a5c447f> in <module>()
# ----> 1 df = df.loc[2:]
#       2 df.index = range(1,len(df)+1)
#       3 df.head(10)
#
# AttributeError: 'NoneType' object has no attribute 'loc'

# %%
df = df.drop(['main use','Building present situation pattern - room',
         'building present situation pattern - hall',
         'building present situation pattern - health',
         'building present situation pattern - compartmented',
         'serial number']
        ,inplace= True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-714fbda7fbce> in <module>()
# ----> 1 df = df.drop(['main use','Building present situation pattern - room',
#       2          'building present situation pattern - hall',
#       3          'building present situation pattern - health',
#       4          'building present situation pattern - compartmented',
#       5          'serial number']
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
df
