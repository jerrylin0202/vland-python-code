# %%
import googlemaps
import urllib.request as request
import pandas as pd
import requests
import json

# %%
my_params = {'summary': '查詢罕用字清單'}
r = requests.get("https://openapi.land.moi.gov.tw/WEBAPI/Rarewords.ashx?description")
r.json()
# Out:
# {'STATUS': 0,
#  'CODE': 999,
#  'MESSAGE': '執行API發生錯誤: 值不能為 null。\r\n參數名稱: key',
#  'RETURNROWS': 0,
#  'RESPONSE': None}

# %%
gmaps = googlemaps.Client(key='AIzaSyDk6DeKSnFNi3H69Ib2oge0HwT2_RdXb0c')

# %%
# location = (25.017156,121.506359)
radius = 25000
place_type = 'restaurant'
places_radar_result = gmaps.places(location = (25.017156,121.506359) ,radius = 25000, type=place_type)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-76a49bb8def4> in <module>
#       3 place_type = 'restaurant'
#       4 places_radar_result = gmaps.places(location = (25.017156,121.506359) ,radius = 25000, type=place_type)
# ----> 5 j = json.loads(places_radar_result, indent = 4)
#       6 j
#
# D:\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not dict

# %%
output = json.dumps(places_radar_result, separators=(',\n', ': '))
output
# Out:
# '{"html_attributions": [],\n"next_page_token": "Aap_uEBfQ-4-2il-_LzJb-0fuSIxokIXJ7o_bZER1iezAOAJ721mrZjI06dwHpWlw6X9pZMJ8qAqccwalOQNF2MXDmMXWc-arZQ9ZySeYujWH5DL46BpcCs3jryLhVh5gOLFR_6tGb6deF-afH8EiieY-265alJjoV1HdPBogOb6lwhhfHGAAGHDF-5UAAbFbMdjqXnjW5cWWNMGMDOM6oOFksSaBP1jYcIQ0V40Y1E1WZnLV4KEnpZuf9E2yse_J_1nPQ5P5K3zXl3j2QgsA97KgnUqE74ZvVa9t7brl21Bjc4YoEfidvluH6D-XMJHckJyMAK76_IVUuj0XCN1FATjFbL6PEYnAWBaCy3H-76wLxyhUXqR7u_jYbTWOdJszJT9sL4AoB0TVtYc2Hw6aSej2X-A82-iMPIFZoVaKmChDrJBjcHrzOVLYd8wpmC2W6VlPAU",\n"results": [{"business_status": "OPERATIONAL",\n"formatted_address": "No. 369, Linsen N Rd, Zhongshan District, Taipei City, 10491",\n"geometry": {"location": {"lat": 25.0578555,\n"lng": 121.5257589},\n"viewport": {"northeast": {"lat": 25.05916587989272,\n"lng": 121.5269861298927},\n"southwest": {"lat": 25.05646622010727,\n"lng": 121.5242864701073}}},\n"icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",\n"icon_background_color": "#FF9E67",\n"icon_mas
# ...
